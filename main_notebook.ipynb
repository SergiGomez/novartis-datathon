# %%
import os
import pandas as pd
import datetime as dt
import sys
import time
import numpy as np

# %%
## Basic execution params
path_data = '/Users/sergigomezpalleja/Downloads/'
user_name = 'sergi'
print_to_log = False

# %%
if print_to_log == True:
    todayDate = dt.datetime.today().strftime('%Y%m%d')
    orig_stdout = sys.stdout
    f = open('main_'+todayDate+ '_'+user_name +'.log', 'w')
    sys.stdout = f

# %%
t0 = time.time()
print("\n-- Data loading  --")
train = pd.read_csv(path_data + 'train_1.csv')
#test = pd.read_csv(path_data + 'key_1.csv')
start_time = time.time()
print("-- Data loading done: %s sec --" % np.round(time.time() - t0,1))
# Out:
# -- Data loading  --
# -- Data loading done: 14.8 sec --

# %%
train.head(n=1)
# Out:
#                                       Page  2015-07-01  2015-07-02  \
# 0  2NE1_zh.wikipedia.org_all-access_spider        18.0        11.0
#
#    2015-07-03  2015-07-04  2015-07-05  2015-07-06  2015-07-07  2015-07-08  \
# 0         5.0        13.0        14.0         9.0         9.0        22.0
#
#    2015-07-09     ...      2016-12-22  2016-12-23  2016-12-24  2016-12-25  \
# 0        26.0     ...            32.0        63.0        15.0        26.0
#
#    2016-12-26  2016-12-27  2016-12-28  2016-12-29  2016-12-30  2016-12-31
# 0        14.0        20.0        22.0        19.0        18.0        20.0
#
# [1 rows x 551 columns]

# %%
train = train.iloc[0:100,]

# %%
train.shape
# Out:
# (100, 551)

# %%
df = train.copy()

# %%
#df = pd.DataFrame(pd.wide_to_long(df, stubnames = '', i = 'Page', j = 'date', sep='', suffix='\\d+'))

# %%
df = pd.melt(df[list(df.columns[-50:])+['Page']], id_vars='Page', var_name='date', value_name='Visits')

# %%
df.head(n=10)
# Out:
#                                                 Page        date  Visits
# 0            2NE1_zh.wikipedia.org_all-access_spider  2016-11-12    13.0
# 1             2PM_zh.wikipedia.org_all-access_spider  2016-11-12    12.0
# 2              3C_zh.wikipedia.org_all-access_spider  2016-11-12     6.0
# 3         4minute_zh.wikipedia.org_all-access_spider  2016-11-12    38.0
# 4  52_Hz_I_Love_You_zh.wikipedia.org_all-access_s...  2016-11-12    13.0
# 5            5566_zh.wikipedia.org_all-access_spider  2016-11-12    22.0
# 6          91Days_zh.wikipedia.org_all-access_spider  2016-11-12    11.0
# 7           A'N'D_zh.wikipedia.org_all-access_spider  2016-11-12    81.0
# 8           AKB48_zh.wikipedia.org_all-access_spider  2016-11-12    25.0
# 9           ASCII_zh.wikipedia.org_all-access_spider  2016-11-12    32.0

# %%
df['date'] = df['date'].astype('datetime64[ns]')
df['weekend'] = ((df.date.dt.dayofweek) // 5 == 1).astype(float)

# %%
df.loc[df.Page == '2NE1_zh.wikipedia.org_all-access_spider']
# Out:
#                                          Page       date  Visits  weekend
# 0     2NE1_zh.wikipedia.org_all-access_spider 2016-11-12    13.0      1.0
# 100   2NE1_zh.wikipedia.org_all-access_spider 2016-11-13     8.0      1.0
# 200   2NE1_zh.wikipedia.org_all-access_spider 2016-11-14    15.0      0.0
# 300   2NE1_zh.wikipedia.org_all-access_spider 2016-11-15    14.0      0.0
# 400   2NE1_zh.wikipedia.org_all-access_spider 2016-11-16    12.0      0.0
# 500   2NE1_zh.wikipedia.org_all-access_spider 2016-11-17     6.0      0.0
# 600   2NE1_zh.wikipedia.org_all-access_spider 2016-11-18    11.0      0.0
# 700   2NE1_zh.wikipedia.org_all-access_spider 2016-11-19    10.0      1.0
# 800   2NE1_zh.wikipedia.org_all-access_spider 2016-11-20    42.0      1.0
# 900   2NE1_zh.wikipedia.org_all-access_spider 2016-11-21    21.0      0.0
# 1000  2NE1_zh.wikipedia.org_all-access_spider 2016-11-22    24.0      0.0
